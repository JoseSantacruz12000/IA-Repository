# %%
import numpy as np

# %% [markdown]
# **Procesamiento de un Neurona Artificial**
#
# Crear el vector de entrada X

# %%
X=np.array([[1],[0.5],[-0.6]])
print(X)
# Out:
# [[ 1. ]
#  [ 0.5]
#  [-0.6]]

# %% [markdown]
# Crear vector de pesos W

# %%
W=np.array([[1.0],[-0.7],[-1.0]])
print(W)
# Out:
# [[ 1. ]
#  [-0.7]
#  [-1. ]]

# %% [markdown]
# Calculo de la neta

# %%
Neta=(np.sum(np.multiply(X,W)))
print(Neta)
# Out:
# 1.25

# %% [markdown]
# Function de activacion sigmoidal

# %%
Y=1.0/(1+np.exp(-Neta))
print(Y)
# Out:
# 0.7772998611746911

# %% [markdown]
# **Procesamiento de una capa de Neuronas**
#
# W y B matricial, Wp(4x3), B(3x1) y X(4x1)

# %%
Wp=np.array([[1.5,0.5, -0.5],[0.7,-0.8, 1.5],[-1.0,1.2, 0.3],[1.0,0.2,-0.3]])
print(Wp)
B=np.array([[0.7],[-0.3],[-0.5]])
print(B)
X=np.array([[1],[0.5],[-0.5],[1]])
print(X)
# Out:
# [[ 1.5  0.5 -0.5]
#  [ 0.7 -0.8  1.5]
#  [-1.   1.2  0.3]
#  [ 1.   0.2 -0.3]]
# [[ 0.7]
#  [-0.3]
#  [-0.5]]
# [[ 1. ]
#  [ 0.5]
#  [-0.5]
#  [ 1. ]]

# %% [markdown]
# Neta matricial

# %%
Neta=((np.matmul(np.transpose(Wp),X))+B)
print(Neta)
# Out:
# [[ 4.05]
#  [-0.6 ]
#  [-0.7 ]]

# %% [markdown]
# Salida Matricial

# %%
Y=1.0/(1+np.exp(-Neta))
print(Y)
# Out:
# [[0.98287597]
#  [0.35434369]
#  [0.33181223]]

# %%
Wp1=np.array([[1.5,0.5, -0.5,-0.5,-0.5],[0.7,-0.8, 1.5,1.5,1.5],[-1.0,1.2, 0.3,0.3,0.3]])
print(Wp1)
B1=np.array([[0.7],[-0.3],[0.5],[-0.2],[0.1]])
print(B1)
# Out:
# [[ 1.5  0.5 -0.5 -0.5 -0.5]
#  [ 0.7 -0.8  1.5  1.5  1.5]
#  [-1.   1.2  0.3  0.3  0.3]]
# [[ 0.7]
#  [-0.3]
#  [ 0.5]
#  [-0.2]
#  [ 0.1]]

# %%
Neta1=((np.matmul((Wp1.T),Y))+B1)
print(Neta1)
# Out:
# [[ 2.09054231]
#  [ 0.3061377 ]
#  [ 0.63962123]
#  [-0.06037877]
#  [ 0.23962123]]

# %%
Y2=1.0/(1+np.exp(-Neta1))
print(Y2)
# Out:
# [[0.88998054]
#  [0.57594224]
#  [0.65466783]
#  [0.48490989]
#  [0.5596203 ]]
